# %% [markdown]
# <a href="https://colab.research.google.com/github/Solomon147/Solomon147.github.io/blob/master/Solomon's_Copy_of_Data_Storytelling_Portfolio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Is soccer a highly talented sport, or a higly atletic/skilled sports?
#
# Soccer is old as 2000 years. One begin to wonder if the actual founders created & predicted the game as a higly talented sport, or a highly atletic sports. I will put together different important characteristics of soccer players against one another, not forgetting the dribbling skill.
#
# There was a study done by University of Queensland that said accurate passing and ball control is more important than speed, strength, or fitness
#
# soccer is based more on athleticism or technique or game knowledge

# %%
# Standard imports 
import pandas as pd
import numpy as np

# Plotting
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
footballers = pd.read_csv('data.csv')






footballers.head()
# Out:
#    Unnamed: 0      ID  ... GKReflexes  Release Clause
# 0           0  158023  ...        8.0         €226.5M
# 1           1   20801  ...       11.0         €127.1M
# 2           2  190871  ...       11.0         €228.1M
# 3           3  193080  ...       94.0         €138.6M
# 4           4  192985  ...       13.0         €196.4M
#
# [5 rows x 89 columns]

# %%
footballers.tail()
# Out:
#        Unnamed: 0      ID  ... GKReflexes  Release Clause
# 18202       18202  238813  ...        9.0           €143K
# 18203       18203  243165  ...       12.0           €113K
# 18204       18204  241638  ...       13.0           €165K
# 18205       18205  246268  ...        9.0           €143K
# 18206       18206  246269  ...        9.0           €165K
#
# [5 rows x 89 columns]

# %%
print(footballers.shape)
# Out:
# (18207, 89)

# %%
#dropping the less important columns 
df_footballers = footballers.drop(['Unnamed: 0', 'ID', 'Photo', 
                                   'Nationality',	'Flag', 'Club', 'Club Logo',	
                                   'Value',	'Wage',	'Special', 
                                   'International Reputation',	'Real Face',	
                                   'Position',	'Jersey Number',	'Joined',	
                                   'Loaned From',	'Contract Valid Until',	'LS',	
                                   'ST',	'RS',	'LW',	'LF',	'CF',	'RF',	'RW',	
                                   'LAM', 'CAM',	'RAM',	'LM',	'LCM', 'CM',	
                                   'RCM',	'RM',	'LWB', 'LDM',	'CDM',	'RDM',	
                                   'RWB',	'LB',	'LCB',	'CB',	'RCB',	'RB',	
                                   'GKDiving',	'GKHandling',	'GKKicking',	
                                   'GKPositioning',	'GKReflexes',	
                                   'Release Clause', 'Preferred Foot', 
                                   'Work Rate', 'Weight', 'Body Type'], axis=1)


df_footballers.head()
# Out:
#                 Name  Age  Overall  ...  Marking  StandingTackle  SlidingTackle
# 0           L. Messi   31       94  ...     33.0            28.0           26.0
# 1  Cristiano Ronaldo   33       94  ...     28.0            31.0           23.0
# 2          Neymar Jr   26       92  ...     27.0            24.0           33.0
# 3             De Gea   27       91  ...     15.0            21.0           13.0
# 4       K. De Bruyne   27       91  ...     68.0            58.0           51.0
#
# [5 rows x 36 columns]

# %%
df_footballers.isnull().sum() #To find out how many missing values my dataset has
# Out:
# Name                0
# Age                 0
# Overall             0
# Potential           0
# Weak Foot          48
# Skill Moves        48
# Height             48
# Crossing           48
# Finishing          48
# HeadingAccuracy    48
# ShortPassing       48
# Volleys            48
# Dribbling          48
# Curve              48
# FKAccuracy         48
# LongPassing        48
# BallControl        48
# Acceleration       48
# SprintSpeed        48
# Agility            48
# Reactions          48
# Balance            48
# ShotPower          48
# Jumping            48
# Stamina            48
# Strength           48
# LongShots          48
# Aggression         48
# Interceptions      48
# Positioning        48
# Vision             48
# Penalties          48
# Composure          48
# Marking            48
# StandingTackle     48
# SlidingTackle      48
# dtype: int64

# %%
df_footballers.isnull().sum().value_counts()
# Out:
# 48    32
# 0      4
# dtype: int64

# %%
df_footballers.dropna(inplace=True) #To remove the rows that has the missing values
print(df_footballers.shape)
# Out:
# (18159, 36)

# %%
df_footballers.isnull().sum()
# Out:
# Name               0
# Age                0
# Overall            0
# Potential          0
# Weak Foot          0
# Skill Moves        0
# Height             0
# Crossing           0
# Finishing          0
# HeadingAccuracy    0
# ShortPassing       0
# Volleys            0
# Dribbling          0
# Curve              0
# FKAccuracy         0
# LongPassing        0
# BallControl        0
# Acceleration       0
# SprintSpeed        0
# Agility            0
# Reactions          0
# Balance            0
# ShotPower          0
# Jumping            0
# Stamina            0
# Strength           0
# LongShots          0
# Aggression         0
# Interceptions      0
# Positioning        0
# Vision             0
# Penalties          0
# Composure          0
# Marking            0
# StandingTackle     0
# SlidingTackle      0
# dtype: int64

# %%
df_footballers.head()
# Out:
#                 Name  Age  Overall  ...  Marking  StandingTackle  SlidingTackle
# 0           L. Messi   31       94  ...     33.0            28.0           26.0
# 1  Cristiano Ronaldo   33       94  ...     28.0            31.0           23.0
# 2          Neymar Jr   26       92  ...     27.0            24.0           33.0
# 3             De Gea   27       91  ...     15.0            21.0           13.0
# 4       K. De Bruyne   27       91  ...     68.0            58.0           51.0
#
# [5 rows x 36 columns]

# %%
soccer = df_footballers.sort_values(by = ['Finishing'],  ascending=False)
soccer.head()
# Out:
#                  Name  Age  Overall  ...  Marking  StandingTackle  SlidingTackle
# 0            L. Messi   31       94  ...     33.0            28.0           26.0
# 1   Cristiano Ronaldo   33       94  ...     28.0            31.0           23.0
# 16            H. Kane   24       89  ...     56.0            36.0           38.0
# 23          S. Agüero   30       89  ...     30.0            20.0           12.0
# 7           L. Suárez   31       91  ...     62.0            45.0           38.0
#
# [5 rows x 36 columns]

# %%
ronaldo = df_footballers.sort_values(by = ['Overall'],  ascending=False)
ronaldo.head()
# Out:
#                 Name  Age  Overall  ...  Marking  StandingTackle  SlidingTackle
# 0           L. Messi   31       94  ...     33.0            28.0           26.0
# 1  Cristiano Ronaldo   33       94  ...     28.0            31.0           23.0
# 2          Neymar Jr   26       92  ...     27.0            24.0           33.0
# 3             De Gea   27       91  ...     15.0            21.0           13.0
# 4       K. De Bruyne   27       91  ...     68.0            58.0           51.0
#
# [5 rows x 36 columns]

# %%
top_five = soccer[soccer.Finishing >= 93] 
top_five.shape

# %%
 finishing_list = list(top_five['Finishing']) 
 finishing_list
# Out:
# [95.0, 94.0, 94.0, 93.0, 93.0]

# %%
#@title Default title text
import matplotlib.pyplot as plt
import numpy as np


# Fixing random state for reproducibility
np.random.seed(19680801)


plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
Names = ('K. De Bruyne', 'Cristiano Ronaldo', 'Neymar Jr', 'De Gea', 'L. Messi')
ronaldo = np.arange(len(Names))
performance = 3 + 10 * np.random.rand(len(Names))
error = np.random.rand(len(Names))

ax.barh(y_pos, performance, xerr=error, align='center')
ax.set_yticks(ronaldo)
ax.set_yticklabels(Names)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Performance')
ax.set_title('L. Messi leads')

plt.show()

# %%
import seaborn as sns
from numpy import mean

# %%
sns.barplot(x = top_five['Name'], y = top_five['Finishing'],estimator= mean)
plt.ylim(90,100)
plt.title('Ball Control/Finishing')
# Out:
# Text(0.5, 1.0, 'Ball Control/Finishing')

# %%
soccer.mean()
# Out:
# Age                25.122529
# Overall            66.249904
# Potential          71.319126
# Weak Foot           2.947299
# Skill Moves         2.361308
# Crossing           49.734181
# Finishing          45.550911
# HeadingAccuracy    52.298144
# ShortPassing       58.686712
# Volleys            42.909026
# Dribbling          55.371001
# Curve              47.170824
# FKAccuracy         42.863153
# LongPassing        52.711933
# BallControl        58.369459
# Acceleration       64.614076
# SprintSpeed        64.726967
# Agility            63.503607
# Reactions          61.836610
# Balance            63.966573
# ShotPower          55.460047
# Jumping            65.089432
# Stamina            63.219946
# Strength           65.311967
# LongShots          47.109973
# Aggression         55.868991
# Interceptions      46.698276
# Positioning        49.958478
# Vision             53.400903
# Penalties          48.548598
# Composure          58.648274
# Marking            47.281623
# ...

# %%
soccer.corr()
# Out:
#                       Age   Overall  ...  StandingTackle  SlidingTackle
# Age              1.000000  0.453069  ...        0.119745       0.103089
# Overall          0.453069  1.000000  ...        0.252629       0.222811
# Potential       -0.252281  0.661180  ...        0.143564       0.128980
# Weak Foot        0.059867  0.212015  ...        0.042646       0.026105
# Skill Moves      0.027649  0.414463  ...        0.210517       0.178607
# Crossing         0.130545  0.394972  ...        0.428963       0.409961
# Finishing        0.068660  0.332515  ...       -0.033023      -0.071811
# HeadingAccuracy  0.147183  0.340776  ...        0.561063       0.533643
# ShortPassing     0.132894  0.502550  ...        0.541131       0.508644
# Volleys          0.142472  0.391338  ...        0.072788       0.035457
# Dribbling        0.010166  0.372426  ...        0.301251       0.273963
# Curve            0.143276  0.419491  ...        0.261481       0.232869
# ...

# %%
sns.scatterplot(x = 'Age', y = 'Potential', data = soccer)

# %%
sns.barplot(x='Dribbling', y ='Overall')

# %%
f, ax = plt.subplots(figsize=(12,12))
sns.heatmap(soccer.corr(),annot=True, linewidths = .5, fmt= '.1f', ax=ax)
plt.show()
